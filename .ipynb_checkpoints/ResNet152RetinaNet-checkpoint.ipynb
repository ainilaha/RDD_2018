# %% [markdown]
# ## Load necessary modules

# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time

# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this environment flag to change which GPU to use
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())
# Out:
# /Users/lahaale/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Load RetinaNet model

# %%
# adjust this to point to your downloaded/trained model
# models can be downloaded here: https://github.com/fizyr/keras-retinanet/releases
model_path = "examples/resnet101_rdd_60_best6985_infer.h5"

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet101')

# if the model is not converted to an inference model, use the line below
# see: https://github.com/fizyr/keras-retinanet#converting-a-training-model-to-inference-model
#model = models.convert_model(model)

#print(model.summary())

# load label to names mapping for visualization purposes
labels_to_names = { 0:'D00',
    1:'D01',
    2:'D10',
    3:'D11',
    4:'D20',
    5:'D40',
    6:'D43',
    7:'D44',
    8:'D30'}
# Out:
# /home/laha/anaconda3/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
import pandas as pd

# %%
test_df = pd.read_csv("/media/sf_Download/road_damage_dataset/testset.csv")

# %%
test_df.head(20)
# Out:
#     Unnamed: 0               file
# 0            0  test_Adachi_00203
# 1            1  test_Adachi_00217
# 2            2  test_Adachi_00001
# 3            3  test_Adachi_00015
# 4            4  test_Adachi_00029
# 5            5  test_Adachi_00175
# 6            6  test_Adachi_00161
# 7            7  test_Adachi_00149
# 8            8  test_Adachi_00148
# 9            9  test_Adachi_00160
# 10          10  test_Adachi_00174
# 11          11  test_Adachi_00028
# 12          12  test_Adachi_00014
# 13          13  test_Adachi_00216
# 14          14  test_Adachi_00202
# 15          15  test_Adachi_00214
# 16          16  test_Adachi_00200
# 17          17  test_Adachi_00228
# 18          18  test_Adachi_00016
# 19          19  test_Adachi_00002

# %% [markdown]
# ## Run detection on example

# %%
# load image
image = read_image_bgr('/media/sf_Download/road_damage_dataset/ImageSets/test_Adachi_00203.jpg')

# copy to draw on
draw = image.copy()
draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
image = preprocess_image(image)
image, scale = resize_image(image)

# process image
image.shape
# Out:
# (600, 600, 3)

# %%
start = time.time()
boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
print("processing time: ", time.time() - start)

# correct for image scale
boxes /= scale

# visualize detections
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
    if score >= 0.0005:
        color = label_color(label)
        b = box.astype(int)
        print("label:",label)
        print("score:",score)
        print("box:",b)

        draw_box(draw, b, color=color)

        caption = "{} {:.3f}".format(labels_to_names[label], score)
        draw_caption(draw, b, caption)
    

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(draw)
plt.show()
# Out:
# processing time:  6.285907030105591
# label: 1
# score: 0.95084137
# box: [273 317 347 598]
# label: 2
# score: 0.055730525
# box: [ 85 462 304 512]

# %%
model_path = "examples/resnet152_rdd_43_best7272_infer.h5"

# load retinanet model
model2 = models.load_model(model_path, backbone_name='resnet152')

# %%
# load image
image = read_image_bgr('/media/sf_Download/road_damage_dataset/ImageSets/test_Chiba_00024.jpg')

# copy to draw on
draw = image.copy()
draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
image = preprocess_image(image)
image, scale = resize_image(image)

# %%
start = time.time()
boxes, scores, labels = model2.predict_on_batch(np.expand_dims(image, axis=0))
print("processing time: ", time.time() - start)

# correct for image scale
boxes /= scale

# visualize detections
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
    if score >= 0.05:
        color = label_color(label)
        b = box.astype(int)
        print("label:",label)
        print("score:",score)
        print("box:",b)

        draw_box(draw, b, color=color)

        caption = "{} {:.3f}".format(labels_to_names[label], score)
        draw_caption(draw, b, caption)
    
plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(draw)
plt.show()
# Out:
# processing time:  7.244978666305542

# %% [markdown]
# # Example of producing submit file

# %%
import progressbar
predict_df = pd.DataFrame(columns=["ImageId", "PredictionString"])

for img in progressbar.progressbar(list(test_df.file.head()), prefix='Parsing annotations: '):    
    img_path = '/media/sf_Download/road_damage_dataset/ImageSets/{}.jpg'.format(img)
    image = read_image_bgr(img_path)
    image = preprocess_image(image)
    image, scale = resize_image(image)
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
 
    boxes /= scale
#     print("ImageId:",img)
    PredictionString =''
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        if score >= 0.5:
            color = label_color(label)
            b = box.astype(int)
#             print("label:",label)
#             print("score:",score)
#             print("box:",b)
            PredictionString += (str(label+1)+' '+str(b).replace("]","").replace("[","").strip()+" ")
    predict_df = predict_df.append({'ImageId': img, 'PredictionString': PredictionString},ignore_index=True)
# Out:
# Parsing annotations: 100% (5 of 5) |#####| Elapsed Time: 0:00:29 Time:  0:00:29

# %%
predict_df.head()
# Out:
#              ImageId                                   PredictionString
# 0  test_Adachi_00203                                 2 273 317 347 598
# 1  test_Adachi_00217                                   7 5 314 599 521
# 2  test_Adachi_00001                                  2 18 232 229 576
# 3  test_Adachi_00015  1 99 115 243 538 1 349 355 596 463 3 349 355 5...
# 4  test_Adachi_00029                                 2 290 208 380 593

# %%
predict_df.to_csv("submit.csv")

# %%
PredictionString =''

# %%
PredictionString
# Out:
# False
